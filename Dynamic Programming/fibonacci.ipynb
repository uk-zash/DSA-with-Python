# %%
def fib(n):
    
    if n<=2:
        return 1
    
    return fib(n-1) + fib(n-2)

# %%
fib(5)   #TC O(2^n)
# Out:
# 5

# %% [markdown]
# Memoization

# %%
def fibonacci(n , memo = {}):

    if n<=2:
        return 1
    
    if n in memo:
        return memo[n]
    else:
        memo[n] = fib(n-1 , memo) + fib(n-2 , memo)
    
    return memo[n]

# %%
fibonacci(50)  # Tc O(n)
# Out:
# 12586269025
